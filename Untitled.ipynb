# %%
import sympy as sp
# %matplotlib inline
sp.init_printing()
from sympy.abc import omega
a,b,c,d,e,f,G,g,h,I_1,j,k,l,m,n_10,o,p,q,r,s,t,u,v,w,x,z,S,S_1,S_2,S_3,S_4,V,W,X,Y,Z = sp.symbols('a b c d e f G g h I_1 j k l m n_10 o p q r s t u v w x z S S_1 S_2 S_3 S_4 V W X Y Z')
Omega = sp.Symbol("Omega")
Gamma = sp.Symbol("Gamma")
B = sp.Matrix([[(S_1 + e + f + Omega), (S_1 + e), (S_2 + g - d), (S_2)],
               [(S_1 - e), (S_1 - e + f - Omega), (S_2), (S_2 + g + d)],
               [(S_4 + g + d), (S_4) , (h+ S_3 + f + Omega), (S_3+h)],
               [(S_4), (S_4 + g -d ), (S_3 - h ), (S_3 - h + f- Omega)]])

y = sp.det(B)
yy = sp.factor(y, Omega)
yyy = sp.Eq(yy, 0)
yyy
# Out:
#  4    3                2 ⎛                                        2
# Ω  + Ω ⋅(2⋅e + 2⋅h) + Ω ⋅⎝-2⋅S₁⋅f - 2⋅S₂⋅g - 2⋅S₃⋅f - 2⋅S₄⋅g + 2⋅d  + 4⋅e⋅h -
#
#    2      2⎞     ⎛
# 2⋅f  - 2⋅g ⎠ + Ω⋅⎝-4⋅S₁⋅f⋅h + 4⋅S₂⋅d⋅f - 4⋅S₂⋅e⋅g - 4⋅S₃⋅e⋅f - 4⋅S₄⋅d⋅f - 4⋅S₄
#
#           2        2          2        2      2        2  ⎞            2
# ⋅g⋅h + 2⋅d ⋅e + 2⋅d ⋅h - 2⋅e⋅f  - 2⋅e⋅g  - 2⋅f ⋅h - 2⋅g ⋅h⎠ + 4⋅S₁⋅S₃⋅f  - 4⋅S
#
#       2         2                        3           2            2
# ₁⋅S₃⋅g  + 2⋅S₁⋅d ⋅f + 4⋅S₁⋅d⋅g⋅h + 2⋅S₁⋅f  - 2⋅S₁⋅f⋅g  - 4⋅S₂⋅S₄⋅f  + 4⋅S₂⋅S₄⋅
#
#  2         2                        2           3         2
# g  - 2⋅S₂⋅d ⋅g + 4⋅S₂⋅d⋅e⋅f - 2⋅S₂⋅f ⋅g + 2⋅S₂⋅g  + 2⋅S₃⋅d ⋅f - 4⋅S₃⋅d⋅e⋅g + 2
#
#      3           2         2                        2           3    4      2
# ⋅S₃⋅f  - 2⋅S₃⋅f⋅g  - 2⋅S₄⋅d ⋅g - 4⋅S₄⋅d⋅f⋅h - 2⋅S₄⋅f ⋅g + 2⋅S₄⋅g  + d  + 4⋅d ⋅
#
#          2  2      2  2    4      2  2    4
# e⋅h + 2⋅d ⋅f  - 2⋅d ⋅g  + f  - 2⋅f ⋅g  + g  = 0

# %%
zz = Omega**4+  W*Omega**3 +  X*Omega**2 + Y* Omega +Z
zzz = sp.Eq(zz,0)
zzz
# Out:
#  4    3      2
# Ω  + Ω ⋅W + Ω ⋅X + Ω⋅Y + Z = 0

# %%
w = sp.Eq(W, 2*e + 2*h) 
w
# Out:
# W = 2⋅e + 2⋅h

# %%
x = sp.Eq(X,-2*S_1*f - 2*S_2*g - 2*S_3*f - 2*S_4*g + 2*d**2 + 4*e*h - 2*f**2 - 2*g**2)

x
# Out:
#                                             2              2      2
# X = -2⋅S₁⋅f - 2⋅S₂⋅g - 2⋅S₃⋅f - 2⋅S₄⋅g + 2⋅d  + 4⋅e⋅h - 2⋅f  - 2⋅g

# %%
y = sp.Eq(Y, -4*S_1*f*h + 4*S_2*d*f - 4*S_2*e*g - 4*S_3*e*f - 4*S_4*d*f - 4*S_4*g*h + 2*d**2*e + 2*d**2*h - 2*e*f**2 - 2*e*g**2 - 2*f**2*h - 2*g**2*h)
y
# Out:
#                                                                           2
# Y = -4⋅S₁⋅f⋅h + 4⋅S₂⋅d⋅f - 4⋅S₂⋅e⋅g - 4⋅S₃⋅e⋅f - 4⋅S₄⋅d⋅f - 4⋅S₄⋅g⋅h + 2⋅d ⋅e
#
#      2          2        2      2        2
# + 2⋅d ⋅h - 2⋅e⋅f  - 2⋅e⋅g  - 2⋅f ⋅h - 2⋅g ⋅h

# %%
z = sp.Eq(Z, 4*S_1*S_3*f**2 - 4*S_1*S_3*g**2 + 2*S_1*d**2*f + 4*S_1*d*g*h + 2*S_1*f**3 - 2*S_1*f*g**2 - 4*S_2*S_4*f**2 + 4*S_2*S_4*g**2 - 2*S_2*d**2*g + 4*S_2*d*e*f - 2*S_2*f**2*g + 2*S_2*g**3 + 2*S_3*d**2*f - 4*S_3*d*e*g + 2*S_3*f**3 - 2*S_3*f*g**2 - 2*S_4*d**2*g - 4*S_4*d*f*h - 2*S_4*f**2*g + 2*S_4*g**3 + d**4 + 4*d**2*e*h + 2*d**2*f**2 - 2*d**2*g**2 + f**4 - 2*f**2*g**2 + g**4)

z
# Out:
#              2            2         2                        3           2
# Z = 4⋅S₁⋅S₃⋅f  - 4⋅S₁⋅S₃⋅g  + 2⋅S₁⋅d ⋅f + 4⋅S₁⋅d⋅g⋅h + 2⋅S₁⋅f  - 2⋅S₁⋅f⋅g  - 4
#
#         2            2         2                        2           3
# ⋅S₂⋅S₄⋅f  + 4⋅S₂⋅S₄⋅g  - 2⋅S₂⋅d ⋅g + 4⋅S₂⋅d⋅e⋅f - 2⋅S₂⋅f ⋅g + 2⋅S₂⋅g  + 2⋅S₃⋅d
#
# 2                        3           2         2                        2
#  ⋅f - 4⋅S₃⋅d⋅e⋅g + 2⋅S₃⋅f  - 2⋅S₃⋅f⋅g  - 2⋅S₄⋅d ⋅g - 4⋅S₄⋅d⋅f⋅h - 2⋅S₄⋅f ⋅g +
#
#       3    4      2          2  2      2  2    4      2  2    4
# 2⋅S₄⋅g  + d  + 4⋅d ⋅e⋅h + 2⋅d ⋅f  - 2⋅d ⋅g  + f  - 2⋅f ⋅g  + g
